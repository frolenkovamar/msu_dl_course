# %% [markdown]
# # Домашнее задание №4
#
# ##### Автор: [Татьяна Гайнцева](https://www.linkedin.com/in/tgaintseva/), @atmyre

# %%
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F

import torchvision
from torchvision import datasets, transforms

from matplotlib import pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# Это домашнее задание состоит из двух частей. В первой части вам нужно реализовать правильную архитектуру сверточной нейросети. Во второй части — подобрать хорошую архитектуру и обучить ее на датасете CIFAR так, чтобы результаты метрики accuracy на тестовой части CIFAR были больше 55%

# %% [markdown]
# ## Задача №1:
# В этом задании вам нужно заполнить пропуски в ячейке ниже, чтобы получилась сверточная нейросеть с заданными параметрами.

# %% [markdown]
# Архитектура сети:
# **conv1 -> maxpool1 -> conv2 -> maxpool2 -> flatten -> fc1 -> fc2**
#
# - conv1: 3 фильтра размера (5, 5);
# - maxpool1: ядро размера 2;
# - conv2: 5 фильтров размера (3, 3);
# - maxpool2: ядро размера 2;
# - fc1: 100 нейронов на выходе;
# - fc2: 10 нейронов на выходе.
#
# После сверточных слоев и первого полносвязного слоя нужно применить функцию активации ReLU с помощью F.ReLU.
#
# **Нейросеть должна работать с изображениями размера 32х32. Никакие дополнительные параметры слоев, кроме указанных выше, задавать не нужно**.

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super().__init__()
        
        # ВАШ КОД ЗДЕСЬ
        # определите слои сети

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=(5,5)) #28x28
        self.pool1 = nn.MaxPool2d(kernel_size=(2,2)) #14x14
        self.conv2 = nn.Conv2d(in_channels=3, out_channels=5, kernel_size=(3,3)) #12x12
        self.pool2 = nn.MaxPool2d(kernel_size=(2,2)) #6x6
        
        self.flatten = nn.Flatten()

        self.fc1 = nn.Linear(6 * 6 * 5, 100)
        self.fc2 = nn.Linear(100, 10)

    
    def forward(self, x):
        # размерность х ~ [64, 3, 32, 32]
        
        # ВАШ КОД ЗДЕСЬ
        # реализуйте forward pass сети

        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        
        x = F.relu(self.conv2(x))
        x = self.pool2(x)

        x = self.flatten(x)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %% [markdown]
# ### Проверка

# %% [markdown]
# Ячейки ниже помогут проверить, что модель написана и работает правильно.

# %%
# Эта ячейка не должна выдавать ошибку. 
# Если при исполнении ячейки возникает ошибка, то в вашей реализации нейросети есть баги.
img = torch.Tensor(np.random.random((32, 3, 32, 32)))
model = ConvNet()
out = model(img)

# %% [markdown]
# Ячейка ниже проверяет, что устройство сети верное.

# %%
# conv1
assert model.conv1.kernel_size == (5, 5), "неверный размер ядра у conv1"
assert model.conv1.in_channels == 3, "неверный размер in_channels у conv1"
assert model.conv1.out_channels == 3, "неверный размер out_channels у conv1"

# pool1
assert model.pool1.kernel_size == (2, 2), "неверный размер ядра у pool1"

# conv2
assert model.conv2.kernel_size == (3, 3), "неверный размер ядра у conv2"
assert model.conv2.in_channels == 3, "неверный размер in_channels у conv2"
assert model.conv2.out_channels == 5, "неверный размер out_channels у conv2"

# pool2
assert model.pool1.kernel_size == (2, 2), "неверный размер ядра у pool2"

# fc1
assert model.fc1.out_features == 100, "неверный размер out_features у fc1"
# fc2
assert model.fc2.out_features == 10, "неверный размер out_features у fc2"

# %% [markdown]
# ### Сдача задания

# %% [markdown]
# Если обе ячейки отработали без ошибок, можно сдавать задание в первую задачу на Я.Контесте.
# Для этого нужно скопировать класс ConvNet в нужное место в `submission_template04.py` и отправить `submission_template04.py` в Я.Контест.

# %% [markdown]
# ## Задача №2:
# Вернемся к задаче классификации картинок [CIFAR](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# __Ваша основная задача: реализовать весь пайплан обучения модели и добиться хорошего значения метрики accuracy на тестовой выборке.__
# Баллы за задание:
# - **0**, если accuracy на тестовой выборке <0.5;
# - **0.5**, если accuracy на тестовой выборке >0.5 и <0.56;
# - **1**, если accuracy на тестовой выборке >0.56;
#
# Код для обучения модели в данном задании полностью реализован. Вам нужно лишь написать код класса нейросети и поэкспериментировать с параметрами так, чтобы получить хорошее качество. В качестве основы архитектуры сети можно взять сеть из задачи №1.

# %% [markdown]
# **! Перед выполнением этого задания рекомендуем включить GPU в настройках колаба.** Это поможет обучать нейросеть быстрее.
#
# Чтобы включить GPU, перейдите Edit->Notebook settings и выберите Hardware accelerator=GPU. Нажмите save.

# %%
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F

import torchvision
from torchvision import datasets, transforms

from matplotlib import pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# Код загрузки данных тот же, что был на занятии. Менять ничего не нужно.

# %%
# загружаем датасет из torchvision
train_data = datasets.CIFAR10(root="./cifar10_data", train=True, download=True, transform=transforms.ToTensor())
test_data = datasets.CIFAR10(root="./cifar10_data", train=False, download=True, transform=transforms.ToTensor())

# делим тренировочную часть на train и val

# в тренировочную выборку отнесем 80% всех картинок
train_size = int(len(train_data) * 0.8)
# в валидационную — остальные 20%
val_size = len(train_data) - train_size

train_data, val_data = torch.utils.data.random_split(train_data, [train_size, val_size])

# заводим даталоадеры, которые будут генерировать батчи
train_loader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=64, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10_data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar10_data/cifar-10-python.tar.gz to ./cifar10_data
# Files already downloaded and verified

# %% [markdown]
# Посмотрим на несколько картинок из датасета:

# %%
# функция отрисовки картинок
def show_images(images, labels):
    f, axes= plt.subplots(1, 10, figsize=(30,5))
    
    for i, axis in enumerate(axes):
        # переводим картинку из тензора в numpy
        img = images[i].numpy()
        # переводим картинку в размерность (длина, ширина, цветовые каналы) 
        img = np.transpose(img, (1, 2, 0))

        axes[i].imshow(img)
        axes[i].set_title(labels[i].numpy())

    plt.show()

# получаем батч картинок
for batch in train_loader:
    images, labels = batch
    break

show_images(images, labels)

# %% [markdown]
# ### Построение модели

# %% [markdown]
# Ниже — ячейка для построения модели. Не стоит сразу делать большую и сложную модель с большим количеством слоев: такая сеть будет обучаться очень долго и, скорее всего, переобучится.
#
# Ваша основная задача – обучить модель и получить качество на отложенной (тестовой выборке) не менее 56% accuracy.
#
# __Внимание: ваша модель должна быть представлена именно переменной `model`.__

# %% [markdown]
# Идеи, что можно попробовать, чтобы улучшить результат сети:
#
# - попробовать разное количество сверточных и полносвязных слоев;
# - попробовать разное количество фильтров в сверточных слоях;
# - попробовать разное количество нейронов в скрытых полносвязных слоях;
# - попробовать добавить/убрать max_pooling;
# - поменять learning_rate;
# - обучать сеть большее количество эпох.
#
# Если ваша модель переобучается (метрика на валидации нацинает становиться хуже), попробуйте уменьшить количество параметров модели. Если модель не переобучается, но показывает плохой результат, попробуйте увеличить количество параметров модели.

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super().__init__()
        
        # ВАШ КОД ЗДЕСЬ
        # определите слои сети
  
        self.network = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1), #32x32 x 32
            nn.ReLU(),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1), #32x32 x 64
            nn.ReLU(),
            nn.MaxPool2d(2, 2), #16x16 x 64

            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1), #16x16 x 128
            nn.ReLU(),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1), #16x16 x 128
            nn.ReLU(),
            nn.MaxPool2d(2, 2), #8x8 x 128

            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1), #8x8 x 256
            nn.ReLU(),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1), #8x8 x 256
            nn.ReLU(),
            nn.MaxPool2d(2, 2), #4x4 x 256

            nn.Flatten(), 
            nn.Linear(256*4*4, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 10))

    
    def forward(self, x):
        # размерность х ~ [64, 3, 32, 32]
        
        # ВАШ КОД ЗДЕСЬ
        # реализуйте forward pass сети

        return self.network(x)

# %%
model = ConvNet()

# %% [markdown]
# Ячейка ниже проверяет, доступен ли GPU и если да, то переносит нейросеть на GPU.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# Функция обучения сети (ее менять не нужно).
#
# Функция выводит текущие значения лосса и accuracy на train выборке каждые 50 итераций обучения. Также после каждой эпохи считается и выводится лосс и accuracy на val выборке. По этим значениям можно понимать, как хорошо обучается ваша модель.

# %%
def evaluate(model, dataloader, loss_fn):
    
    losses = []

    num_correct = 0
    num_elements = 0

    for i, batch in enumerate(dataloader):
        
        # так получаем текущий батч
        X_batch, y_batch = batch
        num_elements += len(y_batch)
        
        with torch.no_grad():
            logits = model(X_batch.to(device))
            
            loss = loss_fn(logits, y_batch.to(device))
            losses.append(loss.item())
            
            y_pred = torch.argmax(logits, dim=1)
            
            num_correct += torch.sum(y_pred.cpu() == y_batch)
    
    accuracy = num_correct / num_elements
            
    return accuracy.numpy(), np.mean(losses)

def train(model, loss_fn, optimizer, n_epoch=3):
    
    # цикл обучения сети
    for epoch in range(n_epoch):

        print("Epoch:", epoch+1)

        model.train(True)
        
        running_losses = []
        running_accuracies = []
        for i, batch in enumerate(train_loader):
            # так получаем текущий батч
            X_batch, y_batch = batch 
            
            # forward pass (получение ответов на батч картинок)
            logits = model(X_batch.to(device)) 
            
            # вычисление лосса от выданных сетью ответов и правильных ответов на батч
            loss = loss_fn(logits, y_batch.to(device)) 
            running_losses.append(loss.item())
            
            loss.backward() # backpropagation (вычисление градиентов)
            optimizer.step() # обновление весов сети
            optimizer.zero_grad() # обнуляем веса
            
            # вычислим accuracy на текущем train батче
            model_answers = torch.argmax(logits, dim=1)
            train_accuracy = torch.sum(y_batch == model_answers.cpu()) / len(y_batch)
            running_accuracies.append(train_accuracy)

            # Логирование результатов
            if (i+1) % 100 == 0:
                print("Средние train лосс и accuracy на последних 50 итерациях:", 
                      np.mean(running_losses), np.mean(running_accuracies), end='\n')

        # после каждой эпохи получаем метрику качества на валидационной выборке
        model.train(False)

        val_accuracy, val_loss = evaluate(model, val_loader, loss_fn=loss_fn)
        print("Эпоха {}/{}: val лосс и accuracy:".format(epoch+1, n_epoch,), 
                      val_loss, val_accuracy, end='\n')
        
    return model

# %% [markdown]
# Запускаем обучение.

# %%
# снова объявим модель
model = ConvNet()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# выбираем функцию потерь
loss_fn = torch.nn.CrossEntropyLoss()

# выбираем алгоритм оптимизации и learning_rate. 
# вы можете экспериментировать с разными значениями learning_rate
learning_rate = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# запустим обучение модели
# параметр n_epoch можно варьировать
model = train(model, loss_fn, optimizer, n_epoch=20)
# Out:
# Epoch: 1
# Средние train лосс и accuracy на последних 50 итерациях: 2.1600853741168975 0.1775
# Средние train лосс и accuracy на последних 50 итерациях: 2.033096514940262 0.23390625
# Средние train лосс и accuracy на последних 50 итерациях: 1.9545100231965382 0.26755208
# Средние train лосс и accuracy на последних 50 итерациях: 1.8848553803563117 0.295625
# Средние train лосс и accuracy на последних 50 итерациях: 1.8308898947238923 0.31840625
# Средние train лосс и accuracy на последних 50 итерациях: 1.7761879994471867 0.33908853
# Эпоха 1/20: val лосс и accuracy: 1.4682154268216177 0.4507
# Epoch: 2
# Средние train лосс и accuracy на последних 50 итерациях: 1.442340463399887 0.47296876
# Средние train лосс и accuracy на последних 50 итерациях: 1.4263437706232072 0.4775
# Средние train лосс и accuracy на последних 50 итерациях: 1.392313578526179 0.4915625
# Средние train лосс и accuracy на последних 50 итерациях: 1.367612494379282 0.50109375
# Средние train лосс и accuracy на последних 50 итерациях: 1.3444994053840638 0.5095
# Средние train лосс и accuracy на последних 50 итерациях: 1.322848730882009 0.5172396
# Эпоха 2/20: val лосс и accuracy: 1.1777649119401434 0.5734
# Epoch: 3
# Средние train лосс и accuracy на последних 50 итерациях: 1.1347044956684114 0.594375
# Средние train лосс и accuracy на последних 50 итерациях: 1.1068169692158698 0.60296875
# Средние train лосс и accuracy на последних 50 итерациях: 1.093212883869807 0.60770833
# Средние train лосс и accuracy на последних 50 итерациях: 1.080773234218359 0.6125
# Средние train лосс и accuracy на последних 50 итерациях: 1.0680131928920746 0.61671877
# Средние train лосс и accuracy на последних 50 итерациях: 1.0601671718557675 0.6197396
# Эпоха 3/20: val лосс и accuracy: 1.0231480325103566 0.637
# Epoch: 4
# Средние train лосс и accuracy на последних 50 итерациях: 0.8880881243944168 0.68109375
# Средние train лосс и accuracy на последних 50 итерациях: 0.8849135130643845 0.68492186
# Средние train лосс и accuracy на последних 50 итерациях: 0.8886587715148926 0.68385416
# Средние train лосс и accuracy на последних 50 итерациях: 0.8878115939348936 0.6848828
# Средние train лосс и accuracy на последних 50 итерациях: 0.8824463523030281 0.68696874
# Средние train лосс и accuracy на последних 50 итерациях: 0.875780201603969 0.6897917
# Эпоха 4/20: val лосс и accuracy: 0.9580845846112367 0.6799
# Epoch: 5
# Средние train лосс и accuracy на последних 50 итерациях: 0.735111474096775 0.7403125
# Средние train лосс и accuracy на последних 50 итерациях: 0.7424902160465717 0.7390625
# Средние train лосс и accuracy на последних 50 итерациях: 0.7293208828568458 0.7447396
# Средние train лосс и accuracy на последних 50 итерациях: 0.7269979650527238 0.7448437
# Средние train лосс и accuracy на последних 50 итерациях: 0.7209356026053428 0.7465
# Средние train лосс и accuracy на последних 50 итерациях: 0.7182082059979439 0.7471354
# Эпоха 5/20: val лосс и accuracy: 0.8339180107329301 0.7157
# Epoch: 6
# Средние train лосс и accuracy на последних 50 итерациях: 0.5478567525744438 0.80515623
# Средние train лосс и accuracy на последних 50 итерациях: 0.5579994019865989 0.80195314
# Средние train лосс и accuracy на последних 50 итерациях: 0.5605286838610967 0.7996354
# Средние train лосс и accuracy на последних 50 итерациях: 0.5745351123064757 0.7951172
# Средние train лосс и accuracy на последних 50 итерациях: 0.57985804438591 0.7949375
# Средние train лосс и accuracy на последних 50 итерациях: 0.5806454153358936 0.7945573
# Эпоха 6/20: val лосс и accuracy: 0.7730806629369213 0.7334
# Epoch: 7
# Средние train лосс и accuracy на последних 50 итерациях: 0.4443221680819988 0.8425
# Средние train лосс и accuracy на последних 50 итерациях: 0.44661805033683777 0.8396875
# Средние train лосс и accuracy на последних 50 итерациях: 0.44330823451280593 0.8411979
# Средние train лосс и accuracy на последних 50 итерациях: 0.4526805026456714 0.83777344
# Средние train лосс и accuracy на последних 50 итерациях: 0.4611594544351101 0.83625
# Средние train лосс и accuracy на последних 50 итерациях: 0.4669738772759835 0.8341146
# Эпоха 7/20: val лосс и accuracy: 0.8630315855050542 0.7242
# Epoch: 8
# Средние train лосс и accuracy на последних 50 итерациях: 0.31410404086112975 0.883125
# Средние train лосс и accuracy на последних 50 итерациях: 0.3088019277900457 0.8888281
# Средние train лосс и accuracy на последних 50 итерациях: 0.3189458565910657 0.88614583
# Средние train лосс и accuracy на последних 50 итерациях: 0.3298624632321298 0.8829687
# Средние train лосс и accuracy на последних 50 итерациях: 0.3389922462552786 0.880125
# Средние train лосс и accuracy на последних 50 итерациях: 0.34223989189912873 0.878125
# Эпоха 8/20: val лосс и accuracy: 0.9583588899320857 0.7254
# Epoch: 9
# Средние train лосс и accuracy на последних 50 итерациях: 0.2111384569853544 0.9267188
# Средние train лосс и accuracy на последних 50 итерациях: 0.22896588053554295 0.91867185
# Средние train лосс и accuracy на последних 50 итерациях: 0.23278061357637247 0.91807294
# Средние train лосс и accuracy на последних 50 итерациях: 0.2426307924836874 0.9142578
# Средние train лосс и accuracy на последних 50 итерациях: 0.25097168833017347 0.91075
# Средние train лосс и accuracy на последних 50 итерациях: 0.2571461852391561 0.9089062
# Эпоха 9/20: val лосс и accuracy: 0.9926350528647185 0.7376
# Epoch: 10
# Средние train лосс и accuracy на последних 50 итерациях: 0.16293423330411316 0.94390625
# Средние train лосс и accuracy на последних 50 итерациях: 0.17197661253623664 0.9403125
# Средние train лосс и accuracy на последних 50 итерациях: 0.18044215058907867 0.9369792
# Средние train лосс и accuracy на последних 50 итерациях: 0.18986518342513592 0.93371093
# Средние train лосс и accuracy на последних 50 итерациях: 0.19596788388863207 0.930625
# Средние train лосс и accuracy на последних 50 итерациях: 0.20102778859746953 0.92903644
# Эпоха 10/20: val лосс и accuracy: 1.1451497288646213 0.7232
# Epoch: 11
# Средние train лосс и accuracy на последних 50 итерациях: 0.12163020985201001 0.95875
# Средние train лосс и accuracy на последних 50 итерациях: 0.15020092711783944 0.94875
# Средние train лосс и accuracy на последних 50 итерациях: 0.16006019967918594 0.94416666
# Средние train лосс и accuracy на последних 50 итерациях: 0.15602808413561434 0.94566405
# Средние train лосс и accuracy на последних 50 итерациях: 0.1620280957557261 0.94359374
# Средние train лосс и accuracy на последних 50 итерациях: 0.167360130706802 0.9420573
# Эпоха 11/20: val лосс и accuracy: 1.2895988210750993 0.7168
# Epoch: 12
# Средние train лосс и accuracy на последних 50 итерациях: 0.09984969685785472 0.9634375
# Средние train лосс и accuracy на последних 50 итерациях: 0.11882124489638954 0.9578906
# Средние train лосс и accuracy на последних 50 итерациях: 0.1292402650322765 0.95421875
# Средние train лосс и accuracy на последних 50 итерациях: 0.12869644166668878 0.95484376
# Средние train лосс и accuracy на последних 50 итерациях: 0.13269167598150672 0.9534375
# Средние train лосс и accuracy на последних 50 итерациях: 0.1371164168557152 0.9524479
# Эпоха 12/20: val лосс и accuracy: 1.2798975846570009 0.7241
# Epoch: 13
# Средние train лосс и accuracy на последних 50 итерациях: 0.09573058531619609 0.969375
# Средние train лосс и accuracy на последних 50 итерациях: 0.0858204784244299 0.9705469
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-e025cbe63f27> in <module>
#       1 # запустим обучение модели
#       2 # параметр n_epoch можно варьировать
# ----> 3 model = train(model, loss_fn, optimizer, n_epoch=20)
#
# <ipython-input-14-156d61683a92> in train(model, loss_fn, optimizer, n_epoch)
#      48             running_losses.append(loss.item())
#      49
# ---> 50             loss.backward() # backpropagation (вычисление градиентов)
#      51             optimizer.step() # обновление весов сети
#      52             optimizer.zero_grad() # обнуляем веса
#
# /usr/local/lib/python3.8/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     394                 create_graph=create_graph,
#     395                 inputs=inputs)
# --> 396         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     397
#     398     def register_hook(self, hook):
#
# /usr/local/lib/python3.8/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     171     # some Python versions print out the first line of a multi-line function
#     172     # calls in the traceback and some print out the last line
# --> 173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# ### Получение метрики качества на тестовой выборке

# %%
test_accuracy, _ = evaluate(model, test_loader, loss_fn)
print('Accuracy на тесте', test_accuracy)
# Out:
# Accuracy на тесте 0.7206

# %% [markdown]
# Вы можете экспериментировать с разным устройством архитектуры нейросети и запускать ее обучение и проверять accuracy на тесте с помощью трех ячеек выше. Когда вы получили нужное значение accuracy на тесте, можете сдавать задание на Я.Контест.

# %% [markdown]
# Проверка, что необходимые пороги пройдены:

# %%
if test_accuracy <= 0.5:
    print("Качество на тесте ниже 0.5, 0 баллов")
elif test_accuracy < 0.56:
    print("Качество на тесте между 0.5 и 0.56, 0.5 баллов")
elif test_accuracy >= 0.56:
    print("Качество на тесте выше 0.56, 1 балл")
# Out:
# Качество на тесте выше 0.56, 1 балл

# %% [markdown]
# ### Сдача задания
# Запустите код ниже для генерации посылки. Полученный файл сдайте в Я.Контест в качестве решения.

# %%
import os

def get_predictions(model, dataloader):
    
    predicted_labels = []
    model.eval()
    predicted_labels = []

    for i, batch in enumerate(dataloader):
        
        # так получаем текущий батч
        X_batch, y_batch = batch
        
        with torch.no_grad():
            logits = model(X_batch.to(device))
            y_pred = torch.argmax(logits, dim=1)
            predicted_labels.append(y_pred)
    
    predicted_labels = torch.cat(predicted_labels)
    return predicted_labels

predicted_labels = get_predictions(model, test_loader)

np.save('submission_hw04.npy', predicted_labels.data.cpu().numpy(), allow_pickle=True)
print('Ответ сохранен в файл `submission_hw04.npy`')
# Out:
# Ответ сохранен в файл `submission_hw04.npy`

# %% [markdown]
# На этом задание завершено. Поздравляем!
